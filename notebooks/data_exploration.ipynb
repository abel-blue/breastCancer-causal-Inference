# %% [markdown]
# # Data exploration (EDA)

# %%
#importing the libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from scipy import stats
import plotly.express as px
import seaborn as sns
sns.set()
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn import preprocessing
import plotly.graph_objects as go
import warnings
warnings.filterwarnings("ignore")

# %%
# importing script modules from ../scripts
# Adding scripts path
import sys, os
sys.path.insert(0, '../scripts/')
from data_preProcessing import data_preProcessing_script
from data_manipulator import DataCleaner
from data_exploration import exploration

# %% [markdown]
# # Load Data

# %%
train_df = pd.read_csv("../data/data.csv")
train_df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    ...  texture_worst  perimeter_worst  area_worst  smoothness_worst  \
# 0  ...          17.33           184.60      2019.0            0.1622
# 1  ...          23.41           158.80      1956.0            0.1238
# 2  ...          25.53           152.50      1709.0            0.1444
# 3  ...          26.50            98.87       567.7            0.2098
# 4  ...          16.67           152.20      1575.0            0.1374
#
#    compactness_worst  concavity_worst  concave points_worst  symmetry_worst  \
# 0             0.6656           0.7119                0.2654          0.4601
# 1             0.1866           0.2416                0.1860          0.2750
# 2             0.4245           0.4504                0.2430          0.3613
# 3             0.8663           0.6869                0.2575          0.6638
# 4             0.2050           0.4000                0.1625          0.2364
#
#    fractal_dimension_worst  Unnamed: 32
# 0                  0.11890          NaN
# 1                  0.08902          NaN
# 2                  0.08758          NaN
# 3                  0.17300          NaN
# 4                  0.07678          NaN
#
# [5 rows x 33 columns]

# %%
preprocess = data_preProcessing_script(train_df)
preprocess.show_data_information()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
#  14  perimeter_se             569 non-null    float64
#  15  area_se                  569 non-null    float64
#  16  smoothness_se            569 non-null    float64
#  17  compactness_se           569 non-null    float64
#  18  concavity_se             569 non-null    float64
#  19  concave points_se        569 non-null    float64
#  20  symmetry_se              569 non-null    float64
#  21  fractal_dimension_se     569 non-null    float64
#  22  radius_worst             569 non-null    float64
#  23  texture_worst            569 non-null    float64
#  24  perimeter_worst          569 non-null    float64
#  25  area_worst               569 non-null    float64
#  26  smoothness_worst         569 non-null    float64
#  27  compactness_worst        569 non-null    float64
#  28  concavity_worst          569 non-null    float64
#  29  concave points_worst     569 non-null    float64
#  30  symmetry_worst           569 non-null    float64
#  31  fractal_dimension_worst  569 non-null    float64
#  32  Unnamed: 32              0 non-null      float64
# dtypes: float64(31), int64(1), object(1)
# memory usage: 146.8+ KB

# %%
print('unique column values')
train_df.apply(lambda x: len(x.unique())).sort_values(ascending=False).head(10)
# Out:
# unique column values
# id                      569
# smoothness_se           547
# fractal_dimension_se    545
# area_worst              544
# concave points_mean     542
# compactness_se          541
# radius_se               540
# area_mean               539
# concavity_worst         539
# compactness_mean        537
# dtype: int64

# %% [markdown]
# # Missing Value Manipulation

# %%
preprocess.colums_WithMissingValue()
# Out:
# ['Unnamed: 32']

# %%
preprocess.get_column_based_missing_percentage()
# Out:
#                          total_missing_values missing_percentage
# id                                          0              0.0 %
# diagnosis                                   0              0.0 %
# radius_mean                                 0              0.0 %
# texture_mean                                0              0.0 %
# perimeter_mean                              0              0.0 %
# area_mean                                   0              0.0 %
# smoothness_mean                             0              0.0 %
# compactness_mean                            0              0.0 %
# concavity_mean                              0              0.0 %
# concave points_mean                         0              0.0 %
# symmetry_mean                               0              0.0 %
# fractal_dimension_mean                      0              0.0 %
# radius_se                                   0              0.0 %
# texture_se                                  0              0.0 %
# perimeter_se                                0              0.0 %
# area_se                                     0              0.0 %
# smoothness_se                               0              0.0 %
# compactness_se                              0              0.0 %
# concavity_se                                0              0.0 %
# concave points_se                           0              0.0 %
# symmetry_se                                 0              0.0 %
# fractal_dimension_se                        0              0.0 %
# radius_worst                                0              0.0 %
# texture_worst                               0              0.0 %
# perimeter_worst                             0              0.0 %
# area_worst                                  0              0.0 %
# smoothness_worst                            0              0.0 %
# compactness_worst                           0              0.0 %
# concavity_worst                             0              0.0 %
# concave points_worst                        0              0.0 %
# symmetry_worst                              0              0.0 %
# fractal_dimension_worst                     0              0.0 %
# Unnamed: 32                               569            100.0 %

# %%
#cols_with_missing = [col for col in train.columns if train[col].isnull().any()]
cols_with_missing = train_df.isnull().sum()
cols_with_missing = cols_with_missing[cols_with_missing>0]
cols_with_missing.sort_values(inplace=True)
fig, ax = plt.subplots(figsize=(7,6))  
width = 0.70 # the width of the bars 
ind = np.arange(len(cols_with_missing))  # the x locations for the groups
ax.barh(ind, cols_with_missing, width, color="violet")
ax.set_yticks(ind+width/2)
ax.set_yticklabels(cols_with_missing.index, minor=False)
plt.xlabel('Count')
plt.ylabel('Features')
# Out:
# Text(0, 0.5, 'Features')

# %% [markdown]
# ##### Unnamed: 32 columns mean nothing so these columns are dropped. Also, except for these columns, there is no missing data.

# %% [markdown]
# ### Fixing missing values

# %%
train_df.drop(["Unnamed: 32"], axis=1, inplace=True)

# %%
preprocess.colums_WithMissingValue()
# Out:
# []

# %% [markdown]
# # Data Wrangling

# %%
preprocess.show_datatypes()
# Out:
# id                           int64
# diagnosis                   object
# radius_mean                float64
# texture_mean               float64
# perimeter_mean             float64
# area_mean                  float64
# smoothness_mean            float64
# compactness_mean           float64
# concavity_mean             float64
# concave points_mean        float64
# symmetry_mean              float64
# fractal_dimension_mean     float64
# radius_se                  float64
# texture_se                 float64
# perimeter_se               float64
# area_se                    float64
# smoothness_se              float64
# compactness_se             float64
# concavity_se               float64
# concave points_se          float64
# symmetry_se                float64
# fractal_dimension_se       float64
# radius_worst               float64
# texture_worst              float64
# perimeter_worst            float64
# area_worst                 float64
# smoothness_worst           float64
# compactness_worst          float64
# concavity_worst            float64
# concave points_worst       float64
# symmetry_worst             float64
# fractal_dimension_worst    float64
# dtype: object

# %%
#Knowing the shapes of our datasets
print('Shapes of our datasets')
print('-----------------------')
print(f'Training dataset:{train_df.shape}')
# Out:
# Shapes of our datasets
# -----------------------
# Training dataset:(569, 32)

# %%
train_df.drop(["id"], axis=1, inplace=True)

# %%
preprocess.show_data_description()
# Out:
#        radius_mean  texture_mean  perimeter_mean    area_mean  \
# count   569.000000    569.000000      569.000000   569.000000
# mean     14.127292     19.289649       91.969033   654.889104
# std       3.524049      4.301036       24.298981   351.914129
# min       6.981000      9.710000       43.790000   143.500000
# 25%      11.700000     16.170000       75.170000   420.300000
# 50%      13.370000     18.840000       86.240000   551.100000
# 75%      15.780000     21.800000      104.100000   782.700000
# max      28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# std           0.014064          0.052813        0.079720             0.038803
# min           0.052630          0.019380        0.000000             0.000000
# 25%           0.086370          0.064920        0.029560             0.020310
# 50%           0.095870          0.092630        0.061540             0.033500
# 75%           0.105300          0.130400        0.130700             0.074000
# max           0.163400          0.345400        0.426800             0.201200
#
#        symmetry_mean  fractal_dimension_mean  ...  radius_worst  \
# count     569.000000              569.000000  ...    569.000000
# mean        0.181162                0.062798  ...     16.269190
# std         0.027414                0.007060  ...      4.833242
# min         0.106000                0.049960  ...      7.930000
# 25%         0.161900                0.057700  ...     13.010000
# 50%         0.179200                0.061540  ...     14.970000
# 75%         0.195700                0.066120  ...     18.790000
# max         0.304000                0.097440  ...     36.040000
#
#        texture_worst  perimeter_worst   area_worst  smoothness_worst  \
# count     569.000000       569.000000   569.000000        569.000000
# mean       25.677223       107.261213   880.583128          0.132369
# std         6.146258        33.602542   569.356993          0.022832
# min        12.020000        50.410000   185.200000          0.071170
# 25%        21.080000        84.110000   515.300000          0.116600
# 50%        25.410000        97.660000   686.500000          0.131300
# 75%        29.720000       125.400000  1084.000000          0.146000
# max        49.540000       251.200000  4254.000000          0.222600
#
#        compactness_worst  concavity_worst  concave points_worst  \
# count         569.000000       569.000000            569.000000
# mean            0.254265         0.272188              0.114606
# std             0.157336         0.208624              0.065732
# min             0.027290         0.000000              0.000000
# 25%             0.147200         0.114500              0.064930
# 50%             0.211900         0.226700              0.099930
# 75%             0.339100         0.382900              0.161400
# max             1.058000         1.252000              0.291000
#
#        symmetry_worst  fractal_dimension_worst
# count      569.000000               569.000000
# mean         0.290076                 0.083946
# std          0.061867                 0.018061
# min          0.156500                 0.055040
# 25%          0.250400                 0.071460
# 50%          0.282200                 0.080040
# 75%          0.317900                 0.092080
# max          0.663800                 0.207500
#
# [8 rows x 30 columns]

# %%
preprocess.drop_duplicates()

# %%
train_df.describe().T.style.bar(subset=['mean'], color='#205ff2')\
                            .background_gradient(subset=['std'], cmap='Reds')\
                            .background_gradient(subset=['50%'], cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_d8280_row0_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#205ff2 1.6%, transparent 1.6%);
# }
# #T_d8280_row0_col2, #T_d8280_row1_col2 {
#   background-color: #fff4ef;
#   color: #000000;
# }
# #T_d8280_row0_col5 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_d8280_row1_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#205ff2 2.2%, transparent 2.2%);
# }
# #T_d8280_row1_col5 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_d8280_row2_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#205ff2 10.4%, transparent 10.4%);
# }
# #T_d8280_row2_col2 {
#   background-color: #ffeee7;
#   color: #000000;
# }
# #T_d8280_row2_col5 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_d8280_row3_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#205ff2 74.4%, transparent 74.4%);
# }
# #T_d8280_row3_col2 {
#   background-color: #f03d2d;
#   color: #f1f1f1;
# }
# #T_d8280_row3_col5 {
#   background-color: #ed8366;
#   color: #f1f1f1;
# }
# #T_d8280_row4_col1, #T_d8280_row5_col1, #T_d8280_row6_col1, #T_d8280_row7_col1, #T_d8280_row8_col1, #T_d8280_row9_col1, #T_d8280_row10_col1, #T_d8280_row14_col1, #T_d8280_row15_col1, #T_d8280_row16_col1, #T_d8280_row17_col1, #T_d8280_row18_col1, #T_d8280_row24_col1, #T_d8280_row25_col1, #T_d8280_row26_col1, #T_d8280_row27_col1, #T_d8280_row28_col1, #T_d8280_row29_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#205ff2 0.0%, transparent 0.0%);
# }
# #T_d8280_row4_col2, #T_d8280_row5_col2, #T_d8280_row6_col2, #T_d8280_row7_col2, #T_d8280_row8_col2, #T_d8280_row9_col2, #T_d8280_row10_col2, #T_d8280_row11_col2, #T_d8280_row12_col2, #T_d8280_row14_col2, #T_d8280_row15_col2, #T_d8280_row16_col2, #T_d8280_row17_col2, #T_d8280_row18_col2, #T_d8280_row19_col2, #T_d8280_row24_col2, #T_d8280_row25_col2, #T_d8280_row26_col2, #T_d8280_row27_col2, #T_d8280_row28_col2, #T_d8280_row29_col2 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_d8280_row4_col5, #T_d8280_row5_col5, #T_d8280_row6_col5, #T_d8280_row7_col5, #T_d8280_row8_col5, #T_d8280_row9_col5, #T_d8280_row10_col5, #T_d8280_row11_col5, #T_d8280_row12_col5, #T_d8280_row14_col5, #T_d8280_row15_col5, #T_d8280_row16_col5, #T_d8280_row17_col5, #T_d8280_row18_col5, #T_d8280_row19_col5, #T_d8280_row24_col5, #T_d8280_row25_col5, #T_d8280_row26_col5, #T_d8280_row27_col5, #T_d8280_row28_col5, #T_d8280_row29_col5 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_d8280_row11_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#205ff2 0.1%, transparent 0.1%);
# }
# #T_d8280_row12_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#205ff2 0.3%, transparent 0.3%);
# }
# #T_d8280_row13_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#205ff2 4.6%, transparent 4.6%);
# }
# #T_d8280_row13_col2 {
#   background-color: #fee8dd;
#   color: #000000;
# }
# #T_d8280_row13_col5, #T_d8280_row21_col5 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_d8280_row19_col1 {
#   width: 10em;
#   height: 80%;
# }
# #T_d8280_row20_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#205ff2 1.8%, transparent 1.8%);
# }
# #T_d8280_row20_col2, #T_d8280_row21_col2 {
#   background-color: #fff4ee;
#   color: #000000;
# }
# #T_d8280_row20_col5 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_d8280_row21_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#205ff2 2.9%, transparent 2.9%);
# }
# #T_d8280_row22_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#205ff2 12.2%, transparent 12.2%);
# }
# #T_d8280_row22_col2 {
#   background-color: #ffebe2;
#   color: #000000;
# }
# #T_d8280_row22_col5 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_d8280_row23_col1 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#205ff2 100.0%, transparent 100.0%);
# }
# #T_d8280_row23_col2 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_d8280_row23_col5 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_d8280_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >count</th>
#       <th class="col_heading level0 col1" >mean</th>
#       <th class="col_heading level0 col2" >std</th>
#       <th class="col_heading level0 col3" >min</th>
#       <th class="col_heading level0 col4" >25%</th>
#       <th class="col_heading level0 col5" >50%</th>
#       <th class="col_heading level0 col6" >75%</th>
#       <th class="col_heading level0 col7" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d8280_level0_row0" class="row_heading level0 row0" >radius_mean</th>
#       <td id="T_d8280_row0_col0" class="data row0 col0" >569.000000</td>
#       <td id="T_d8280_row0_col1" class="data row0 col1" >14.127292</td>
#       <td id="T_d8280_row0_col2" class="data row0 col2" >3.524049</td>
#       <td id="T_d8280_row0_col3" class="data row0 col3" >6.981000</td>
#       <td id="T_d8280_row0_col4" class="data row0 col4" >11.700000</td>
#       <td id="T_d8280_row0_col5" class="data row0 col5" >13.370000</td>
#       <td id="T_d8280_row0_col6" class="data row0 col6" >15.780000</td>
#       <td id="T_d8280_row0_col7" class="data row0 col7" >28.110000</td>
#     </tr>
#     <tr>
#       <th id="T_d8280_level0_row1" class="row_heading level0 row1" >texture_mean</th>
#       <td id="T_d8280_row1_col0" class="data row1 col0" >569.000000</td>
#       <td id="T_d8280_row1_col1" class="data row1 col1" >19.289649</td>
#       <td id="T_d8280_row1_col2" class="data row1 col2" >4.301036</td>
#       <td id="T_d8280_row1_col3" class="data row1 col3" >9.710000</td>
#       <td id="T_d8280_row1_col4" class="data row1 col4" >16.170000</td>
#       <td id="T_d8280_row1_col5" class="data row1 col5" >18.840000</td>
#       <td id="T_d8280_row1_col6" class="data row1 col6" >21.800000</td>
#       <td id="T_d8280_row1_col7" class="data row1 col7" >39.280000</td>
#     </tr>
#     <tr>
#       <th id="T_d8280_level0_row2" class="row_heading level0 row2" >perimeter_mean</th>
#       <td id="T_d8280_row2_col0" class="data row2 col0" >569.000000</td>
#       <td id="T_d8280_row2_col1" class="data row2 col1" >91.969033</td>
#       <td id="T_d8280_row2_col2" class="data row2 col2" >24.298981</td>
#       <td id="T_d8280_row2_col3" class="data row2 col3" >43.790000</td>
#       <td id="T_d8280_row2_col4" class="data row2 col4" >75.170000</td>
#       <td id="T_d8280_row2_col5" class="data row2 col5" >86.240000</td>
#       <td id="T_d8280_row2_col6" class="data row2 col6" >104.100000</td>
#       <td id="T_d8280_row2_col7" class="data row2 col7" >188.500000</td>
#     </tr>
#     <tr>
#       <th id="T_d8280_level0_row3" class="row_heading level0 row3" >area_mean</th>
#       <td id="T_d8280_row3_col0" class="data row3 col0" >569.000000</td>
#       <td id="T_d8280_row3_col1" class="data row3 col1" >654.889104</td>
#       <td id="T_d8280_row3_col2" class="data row3 col2" >351.914129</td>
#       <td id="T_d8280_row3_col3" class="data row3 col3" >143.500000</td>
#       <td id="T_d8280_row3_col4" class="data row3 col4" >420.300000</td>
#       <td id="T_d8280_row3_col5" class="data row3 col5" >551.100000</td>
#       <td id="T_d8280_row3_col6" class="data row3 col6" >782.700000</td>
#       <td id="T_d8280_row3_col7" class="data row3 col7" >2501.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d8280_level0_row4" class="row_heading level0 row4" >smoothness_mean</th>
#       <td id="T_d8280_row4_col0" class="data row4 col0" >569.000000</td>
#       <td id="T_d8280_row4_col1" class="data row4 col1" >0.096360</td>
#       <td id="T_d8280_row4_col2" class="data row4 col2" >0.014064</td>
#       <td id="T_d8280_row4_col3" class="data row4 col3" >0.052630</td>
#       <td id="T_d8280_row4_col4" class="data row4 col4" >0.086370</td>
#       <td id="T_d8280_row4_col5" class="data row4 col5" >0.095870</td>
#       <td id="T_d8280_row4_col6" class="data row4 col6" >0.105300</td>
#       <td id="T_d8280_row4_col7" class="data row4 col7" >0.163400</td>
#     </tr>
#     <tr>
#       <th id="T_d8280_level0_row5" c

# %%
train_df.head()
# Out:
#   diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0         M        17.99         10.38          122.80     1001.0
# 1         M        20.57         17.77          132.90     1326.0
# 2         M        19.69         21.25          130.00     1203.0
# 3         M        11.42         20.38           77.58      386.1
# 4         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# 0         0.2419  ...         25.38          17.33           184.60
# 1         0.1812  ...         24.99          23.41           158.80
# 2         0.2069  ...         23.57          25.53           152.50
# 3         0.2597  ...         14.91          26.50            98.87
# 4         0.1809  ...         22.54          16.67           152.20
#
#    area_worst  smoothness_worst  compactness_worst  concavity_worst  \
# 0      2019.0            0.1622             0.6656           0.7119
# 1      1956.0            0.1238             0.1866           0.2416
# 2      1709.0            0.1444             0.4245           0.4504
# 3       567.7            0.2098             0.8663           0.6869
# 4      1575.0            0.1374             0.2050           0.4000
#
#    concave points_worst  symmetry_worst  fractal_dimension_worst
# 0                0.2654          0.4601                  0.11890
# 1                0.1860          0.2750                  0.08902
# 2                0.2430          0.3613                  0.08758
# 3                0.2575          0.6638                  0.17300
# 4                0.1625          0.2364                  0.07678
#
# [5 rows x 31 columns]

# %%
# save the clean dataframe to a csv file
train_df.to_csv('../data/data.csv', index=False) # version 2 - id removed

# %%
# y includes our outcome label and X includes our features
y = train_df.diagnosis # M or B 
list_drp = ['diagnosis']
X = train_df.drop(list_drp,axis = 1 )

# %% [markdown]
# # Univariate Analysis

# %%
exploration = exploration()

# %%
exploration.plot_count(train_df, 'diagnosis')

# %%
train_df["diagnosis"].value_counts()
# Out:
# B    357
# M    212
# Name: diagnosis, dtype: int64

# %%
# Check normal distribution of all numerical features
test_normality = lambda x: stats.shapiro(x.fillna(0))[1] < 0.01
normal = pd.DataFrame(X)
normal = normal.apply(test_normality)
print(not normal.any())
# Out:
# False

# %% [markdown]
# # Bivariate Analysis

# %% [markdown]
# # Outliers

# %%
from data_exploration import exploration
exploration = exploration()

# %%
train_df.columns

# %%
exploration.plot_box(train_df, 'radius_mean', 'Outliers')

# %%
exploration.plot_box(train_df, 'perimeter_mean', 'Outliers')

# %%
exploration.plot_box(train_df, 'smoothness_mean', 'Outliers')

# %%
exploration.plot_box(train_df, 'concavity_se', 'Outliers')

# %% [markdown]
# # Correlation Analysis
